# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# ## My Jupiter NoteBook on IBM Watson Studio

# %% [markdown]
# <b>Lowri Lewis</b>
# <br> Desired occupation: Bioinformatician/Data Scientist

# %% [markdown]
# <i> I am interested in data science as I think its fascinating to extract so much meaningful information from datasets containing seemingly uninteresting information. I enjoy coding and am hoping to implement my skills in both the business and health sectors to better understand the implications of data science in both sectors</i>

# %% [markdown]
# ### The code in cell 5 aims to conquer an impossible addition

# %%
1+1
# Out:
# 2

# %% [markdown]
# |Animal|Number of legs|Cuteness factor (0-10)|
# |---|---|---|
# |Dog|4|10|
# |Guinea Pig|4|10|
# |Chicken|2|3|
# |Dolphin|0|8|
#
# ![Cute dog](https://kb.rspca.org.au/wp-content/uploads/2018/11/golder-retriever-puppy.jpeg)
#
# [This is a cool website](https://theuselessweb.com/)
#
# #### What I have included in this cell:
# - table
# - image
# - hyperlink
# - h4 heading
# - bulleted list
